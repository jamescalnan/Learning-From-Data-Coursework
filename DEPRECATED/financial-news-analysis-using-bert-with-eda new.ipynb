# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing  import LabelEncoder
le = LabelEncoder()
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")
import missingno as miss
from collections import Counter
import matplotlib.pyplot as plt
import plotly.express as px
from plotly.offline import iplot
import cufflinks as cf
cf.go_offline()
from tqdm import tqdm

from nltk.corpus import stopwords    
from nltk.tokenize import word_tokenize
from textblob import TextBlob

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, LSTM, Embedding, Dropout, Activation, SpatialDropout1D, MaxPooling1D, Conv1D, Concatenate, Bidirectional, GlobalMaxPool1D, ActivityRegularization, BatchNormalization
from keras.models import Model
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score,confusion_matrix
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv("all-data.csv", encoding='latin-1', header = None)
df.columns = ["Sentiment", "News Headline"]
df.head()
# Out:
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...

# %%
df.shape
# Out:
# (4846, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4846 entries, 0 to 4845
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Sentiment      4846 non-null   object
#  1   News Headline  4846 non-null   object
# dtypes: object(2)
# memory usage: 75.8+ KB

# %%
df.describe(include = "all")
# Out:
#        Sentiment                                      News Headline
# count       4846                                               4846
# unique         3                                               4838
# top      neutral  TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sel...
# freq        2879                                                  2

# %%
df.isna().sum()
# Out:
# Sentiment        0
# News Headline    0
# dtype: int64

# %%
miss.bar(df)
plt.show()

# %%
#check for duplicates

len(df[df.duplicated()])
# Out:
# 6

# %%
df = df.drop_duplicates()
print(df.head())
print(df.shape)
# Out:
#   Sentiment                                      News Headline
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
# 3  positive  With the new production plant the company woul...
# 4  positive  According to the company 's updated strategy f...
# (4840, 2)

# %% [markdown]
# ## Number of Characters

# %%
df['nr_of_char'] = df['News Headline'].str.len()
df['nr_of_char'] = df['nr_of_char'] / df['nr_of_char'].max()
df[['Sentiment', 'nr_of_char']].pivot(columns = 'Sentiment', values = 'nr_of_char').iplot(kind = 'box')
# Out:
# <div>                            <div id="772320e8-c283-4627-a0f0-3742dbbdec44" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("772320e8-c283-4627-a0f0-3742dbbdec44")) {                    Plotly.newPlot(                        "772320e8-c283-4627-a0f0-3742dbbdec44",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"negative","orientation":"v","y":[null,null,0.7238095238095238,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.4857142857142857,null,null,null,null,null,0.40634920634920635,null,0.40634920634920635,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.3968253968253968,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.37777777777777777,null,null,0.2857142857142857,0.4380952380952381,0.21904761904761905,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.7396825396825397,0.7301587301587301,0.37142857142857144,0.2984126984126984,0.7428571428571429,0.29206349 ...

# %% [markdown]
# ## Number of words

# %%
df['nr_of_words'] = df['News Headline'].str.split().str.len()
df['nr_of_words'] = df['nr_of_words'] / df['nr_of_char'].max()
df[['Sentiment', 'nr_of_words']].pivot(columns = 'Sentiment', values = 'nr_of_words').iplot(kind = 'box')
# Out:
# <div>                            <div id="b6427649-2efa-443c-943d-c0812d69798a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("b6427649-2efa-443c-943d-c0812d69798a")) {                    Plotly.newPlot(                        "b6427649-2efa-443c-943d-c0812d69798a",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"negative","orientation":"v","y":[null,null,36.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,29.0,null,null,null,null,null,30.0,null,30.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,23.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,24.0,null,null,19.0,22.0,13.0,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,43.0,49.0,21.0,19.0,47.0,19.0,42.0,25.0,24.0,44.0,44.0,18.0,28.0,16.0,14.0,30.0,null,null,null,null,null,null,null,null,9.0,null,null,42.0,47.0,42.0,16.0,38.0,null,null,null,null,null,null,null,null,null,null,null,16.0,null,null,null,nu ...

# %% [markdown]
# ## Number of unique words

# %%
df['nr_of_unique_words'] = df['News Headline'].apply(lambda x: len(set(x.split())))
df['nr_of_unique_words'] = df['nr_of_unique_words'] / df['nr_of_unique_words'].max()
df[['Sentiment', 'nr_of_unique_words']].pivot(columns = 'Sentiment', values = 'nr_of_unique_words').iplot(kind='box')
# Out:
# <div>                            <div id="bee29d85-4bdb-4d09-b39c-8ce5322408b0" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("bee29d85-4bdb-4d09-b39c-8ce5322408b0")) {                    Plotly.newPlot(                        "bee29d85-4bdb-4d09-b39c-8ce5322408b0",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"negative","orientation":"v","y":[null,null,0.6739130434782609,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.5869565217391305,null,null,null,null,null,0.5869565217391305,null,0.5869565217391305,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.41304347826086957,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.4782608695652174,null,null,0.391304347826087,0.4782608695652174,0.2608695652173913,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.8260869565217391,0.8695652173913043,0.391304347826087,0.34782608695652173,0.8478260869565217,0.3043478260869 ...

# %% [markdown]
# ## Number of punctuation marks

# %%
df['nr_of_punctuation'] = df['News Headline'].str.split(r"\?|,|\.|\!|\"|'").str.len()
df['nr_of_punctuation'] = df['nr_of_punctuation'] / df['nr_of_punctuation'].max()
df[['Sentiment', 'nr_of_punctuation']].pivot(columns = 'Sentiment', values = 'nr_of_punctuation').iplot(kind = 'box')
# Out:
# <div>                            <div id="1a6c4c3c-a893-4b7e-8ff0-0d65099031fa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("1a6c4c3c-a893-4b7e-8ff0-0d65099031fa")) {                    Plotly.newPlot(                        "1a6c4c3c-a893-4b7e-8ff0-0d65099031fa",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"negative","orientation":"v","y":[null,null,0.08333333333333333,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.05555555555555555,null,null,null,null,null,0.19444444444444445,null,0.19444444444444445,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.05555555555555555,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.1111111111111111,null,null,0.1111111111111111,0.05555555555555555,0.08333333333333333,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.1111111111111111,0.1388888888888889,0.1111111111111111,0.1111111111111111,0.1111111111111111,0.111111 ...

# %% [markdown]
# ## Number of stopwords

# %%
stop_words = set(stopwords.words('english'))
df['nr_of_stopwords'] = df['News Headline'].str.split().apply(lambda x: len(set(x) & stop_words))
df['nr_of_stopwords'] = df['nr_of_stopwords'] / df['nr_of_stopwords'].max()
df[['Sentiment', 'nr_of_stopwords']].pivot(columns = 'Sentiment', values = 'nr_of_stopwords').iplot(kind = 'box')
# Out:
# <div>                            <div id="fa2e27a5-7d4e-4e0c-85f3-3c2c2d121d14" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("fa2e27a5-7d4e-4e0c-85f3-3c2c2d121d14")) {                    Plotly.newPlot(                        "fa2e27a5-7d4e-4e0c-85f3-3c2c2d121d14",                        [{"boxpoints":false,"line":{"width":1.3},"marker":{"color":"rgba(255, 153, 51, 1.0)"},"name":"negative","orientation":"v","y":[null,null,0.3888888888888889,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.3333333333333333,null,null,null,null,null,0.5,null,0.5,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.3888888888888889,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.3333333333333333,null,null,0.3333333333333333,0.4444444444444444,0.16666666666666666,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.4444444444444444,0.5,0.2222222222222222,0.2777777777777778,0.5,0.2222222222222222,0.3888888888888889,0.3888888888888889,0.333333333333333 ...

# %% [markdown]
# ## Feature correlation matrix

# %%
# df.corr().iplot(kind='heatmap',colorscale="YlGnBu",title="Feature Correlation Matrix")

# %% [markdown]
# ## Target Distribution

# %%
df.insert(0, 'Id', range(1, 1 + len(df))) #defining custom Id column
def show_donut_plot(col): #donut plot function
    
    rating_data = df.groupby(col)[['Id']].count().head(10)
    plt.figure(figsize = (12, 8))
    plt.pie(rating_data[['Id']], autopct = '%1.0f%%', startangle = 140, pctdistance = 1.1, shadow = True)

    # create a center circle for more aesthetics to make it better
    gap = plt.Circle((0, 0), 0.5, fc = 'white')
    fig = plt.gcf()
    fig.gca().add_artist(gap)
    
    plt.axis('equal')
    
    cols = []
    for index, row in rating_data.iterrows():
        cols.append(index)
    plt.legend(cols)
    
    plt.title('Donut Plot: Reviews \n', loc='center')
    plt.show()

# %%
# show_donut_plot('Sentiment')

# %% [markdown]
# ## Cleaning the text column

# %%
import re
import spacy

# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

def normalize(msg):
    msg = re.sub('[^A-Za-z]+', ' ', msg)  # remove special character and integers
    doc = nlp(msg)
    res = []
    for token in doc:
        if(token.is_stop or token.is_punct or token.is_currency or token.is_space or len(token.text) <= 2):  # word filtration
            pass
        else:
            res.append(token.lemma_.lower())
    return res

# %%
df["News Headline"] = df["News Headline"].apply(normalize)

# %%
df.head()
# Out:
#    Id Sentiment                                      News Headline  \
# 0   1   neutral  [accord, gran, company, plan, production, russ...
# 1   2   neutral  [technopoli, plan, develop, stage, area, squar...
# 2   3  negative  [international, electronic, industry, company,...
# 3   4  positive  [new, production, plant, company, increase, ca...
# 4   5  positive  [accord, company, update, strategy, year, basw...
#
#    nr_of_char  nr_of_words  nr_of_unique_words  nr_of_punctuation  \
# 0    0.403175         25.0            0.413043           0.111111
# 1    0.603175         31.0            0.608696           0.111111
# 2    0.723810         36.0            0.673913           0.083333
# 3    0.653968         33.0            0.521739           0.055556
# 4    0.644444         41.0            0.695652           0.111111
#
#    nr_of_stopwords
# 0         0.444444
# 1         0.444444
# 2         0.388889
# 3         0.333333
# 4         0.444444

# %%
words_collection = Counter([item for sublist in df['News Headline'] for item in sublist])
freq_word_df = pd.DataFrame(words_collection.most_common(20))
freq_word_df.columns = ['frequently_used_word','count']

# %%
fig = px.scatter(freq_word_df, x="frequently_used_word", y="count", color="count", title = 'Frequently used words - Scatter plot')
fig.show()
# Out:
# <div>                            <div id="310520fe-c37d-45fa-8a4c-6e62cc25642d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("310520fe-c37d-45fa-8a4c-6e62cc25642d")) {                    Plotly.newPlot(                        "310520fe-c37d-45fa-8a4c-6e62cc25642d",                        [{"hovertemplate":"frequently_used_word=%{x}\u003cbr\u003ecount=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[1415,968,596,524,497,446,442,433,414,414,352,328,309,291,291,288,279,268,262,250],"coloraxis":"coloraxis","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":["eur","company","say","finnish","sale","year","million","share","net","profit","finland","group","service","business","mln","market","new","period","quarter","total"],"xaxis":"x","y":[1415,968,596,524,497,446,442,433,414,414,352,328,309,291,291,288,279,268,262,250],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5 ...

# %%
df["News Headline"] = df["News Headline"].apply(lambda x : " ".join(x))
df = df[["News Headline", "Sentiment"]]
df["Sentiment"] = le.fit_transform(df["Sentiment"])
df.head()
# Out:
#                                        News Headline  Sentiment
# 0  accord gran company plan production russia com...          1
# 1  technopoli plan develop stage area square mete...          1
# 2  international electronic industry company elco...          0
# 3  new production plant company increase capacity...          2
# 4  accord company update strategy year basware ta...          2

# %% [markdown]
# ## Let's start with BERT

# %%
rename = {"News Headline": "text", "Sentiment": "labels"}
df.rename(columns = rename, inplace=True)

# %%
# !pip install transformers
# !pip install simpletransformers
# Out:
# Requirement already satisfied: transformers in /home/calnan/.local/lib/python3.8/site-packages (4.24.0)
# Requirement already satisfied: packaging>=20.0 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (23.0)
# Requirement already satisfied: tqdm>=4.27 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (4.64.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers) (5.3.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (0.19.4)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from transformers) (2.22.0)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: filelock in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (3.9.0)
# Requirement already satisfied: numpy>=1.17 in /home/calnan/.local/lib/python3.8/site-packages (from transformers) (1.24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/calnan/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (4.8.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/calnan/.local/lib/python3.8/site-packages (from huggingface-hub<1.0,>=0.10.0->transformers) (2023.10.0)
# Requirement already satisfied: simpletransformers in /home/calnan/.local/lib/python3.8/site-packages (0.63.11)
# Requirement already satisfied: transformers>=4.6.0 in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (4.24.0)
# Requirement already satisfied: datasets in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (2.14.6)
# Requirement already satisfied: scikit-learn in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (1.3.0)
# Requirement already satisfied: numpy in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (1.24.2)
# Requirement already satisfied: wandb>=0.10.32 in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (0.16.0)
# Requirement already satisfied: scipy in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (1.10.1)
# Requirement already satisfied: tqdm>=4.47.0 in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (4.64.1)
# Requirement already satisfied: sentencepiece in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (0.1.99)
# Requirement already satisfied: tokenizers in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (0.13.3)
# Requirement already satisfied: requests in /usr/lib/python3/dist-packages (from simpletransformers) (2.22.0)
# Requirement already satisfied: pandas in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (2.0.3)
# Requirement already satisfied: regex in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (2022.10.31)
# Requirement already satisfied: tensorboard in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (2.13.0)
# Requirement already satisfied: streamlit in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (1.28.1)
# Requirement already satisfied: seqeval in /home/calnan/.local/lib/python3.8/site-packages (from simpletransformers) (1.2.2)
# Requirement already satisfied: packaging>=20.0 in /home/calnan/.local/lib/python3.8/site-packages (from transformers>=4.6.0->simpletransformers) (23.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.10.0 in /home/calnan/.local/lib/python3.8/site-packages (from transformers>=4.6.0->simpletransformers) (0.19.4)
# Requirement already satisfied: filelock in /home/calnan/.local/lib/python3.8/site-packages (from transformers>=4.6.0->simpletransformers) (3.9.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/lib/python3/dist-packages (from transformers>=4.6.0->simpletransformers) (5.3.1)
# Requirement already satisfied: multiprocess in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (0.70.15)
# Requirement already satisfied: aiohttp in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (3.8.6)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (2023.10.0)
# Requirement already satisfied: pyarrow>=8.0.0 in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (14.0.1)
# Requirement already satisfied: xxhash in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (3.4.1)
# Requirement already satisfied: dill<0.3.8,>=0.3.0 in /home/calnan/.local/lib/python3.8/site-packages (from datasets->simpletransformers) (0.3.7)
# Requirement already satisfied: joblib>=1.1.1 in /home/calnan/.local/lib/python3.8/site-packages (from scikit-learn->simpletransformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/calnan/.local/lib/python3.8/site-packages (from scikit-learn->simpletransformers) (3.2.0)
# Requirement already satisfied: setproctitle in /usr/lib/python3/dist-packages (from wandb>=0.10.32->simpletransformers) (1.1.10)
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (8.1.7)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (1.34.0)
# Requirement already satisfied: psutil>=5.0.0 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (5.8.0)
# Requirement already satisfied: appdirs>=1.4.3 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (1.4.4)
# Requirement already satisfied: typing-extensions; python_version < "3.10" in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (4.8.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (0.4.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wandb>=0.10.32->simpletransformers) (45.2.0)
# Requirement already satisfied: GitPython!=3.1.29,>=1.0.0 in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (3.1.40)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.12.0; python_version < "3.9" and sys_platform == "linux" in /home/calnan/.local/lib/python3.8/site-packages (from wandb>=0.10.32->simpletransformers) (4.24.1)
# Requirement already satisfied: tzdata>=2022.1 in /home/calnan/.local/lib/python3.8/site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: pytz>=2020.1 in /home/calnan/.local/lib/python3.8/site-packages (from pandas->simpletransformers) (2023.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/calnan/.local/lib/python3.8/site-packages (from pandas->simpletransformers) (2.8.2)
# Requirement already satisfied: absl-py>=0.4 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (2.22.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (2.3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (0.7.1)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard->simpletransformers) (0.34.2)
# Requirement already satisfied: grpcio>=1.48.2 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (1.57.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/calnan/.local/lib/python3.8/site-packages (from tensorboard->simpletransformers) (3.4.4)
# Requirement already satisfied: altair<6,>=4.0 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.1.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (10.1.0)
# Requirement already satisfied: validators<1,>=0.2 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.22.0)
# Requirement already satisfied: tzlocal<6,>=1.1 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.10.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (5.3.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (6.3.3)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (0.8.1b0)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (13.3.1)
# Requirement already satisfied: watchdog>=2.1.5; platform_system != "Darwin" in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (3.0.0)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (8.2.3)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit->simpletransformers) (1.4)
# Requirement already satisfied: importlib-metadata<7,>=1.4 in /home/calnan/.local/lib/python3.8/site-packages (from streamlit->simpletransformers) (6.8.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (3.3.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.3.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (1.9.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/calnan/.local/lib/python3.8/site-packages (from aiohttp->datasets->simpletransformers) (4.0.3)
# Requirement already satisfied: certifi in /usr/lib/python3/dist-packages (from sentry-sdk>=1.0.0->wandb>=0.10.32->simpletransformers) (2019.11.28)
# Requirement already satisfied: urllib3>=1.26.11; python_version >= "3.6" in /home/calnan/.local/lib/python3.8/site-packages (from sentry-sdk>=1.0.0->wandb>=0.10.32->simpletransformers) (1.26.18)
# Requirement already satisfied: six>=1.4.0 in /usr/lib/python3/dist-packages (from docker-pycreds>=0.4.0->wandb>=0.10.32->simpletransformers) (1.14.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/calnan/.local/lib/python3.8/site-packages (from GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (4.0.11)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/calnan/.local/lib/python3.8/site-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/lib/python3/dist-packages (from google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/calnan/.local/lib/python3.8/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/calnan/.local/lib/python3.8/site-packages (from werkzeug>=1.0.1->tensorboard->simpletransformers) (2.1.3)
# Requirement already satisfied: toolz in /home/calnan/.local/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: jsonschema>=3.0 in /home/calnan/.local/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (4.19.2)
# Requirement already satisfied: jinja2 in /home/calnan/.local/lib/python3.8/site-packages (from altair<6,>=4.0->streamlit->simpletransformers) (3.1.2)
# Requirement already satisfied: backports.zoneinfo; python_version < "3.9" in /home/calnan/.local/lib/python3.8/site-packages (from tzlocal<6,>=1.1->streamlit->simpletransformers) (0.2.1)
# Requirement already satisfied: pygments<3.0.0,>=2.14.0 in /home/calnan/.local/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.14.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.1.0 in /home/calnan/.local/lib/python3.8/site-packages (from rich<14,>=10.14.0->streamlit->simpletransformers) (2.2.0)
# Requirement already satisfied: zipp>=0.5 in /home/calnan/.local/lib/python3.8/site-packages (from importlib-metadata<7,>=1.4->streamlit->simpletransformers) (3.16.2)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp->datasets->simpletransformers) (2.8)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/calnan/.local/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb>=0.10.32->simpletransformers) (5.0.1)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/lib/python3/dist-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard->simpletransformers) (0.4.2)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/lib/python3/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->simpletransformers) (3.1.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/calnan/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.12.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/calnan/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (6.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/calnan/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/calnan/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (0.30.2)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10; python_version < "3.9" in /home/calnan/.local/lib/python3.8/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->simpletransformers) (1.3.10)
# Requirement already satisfied: mdurl~=0.1 in /home/calnan/.local/lib/python3.8/site-packages (from markdown-it-py<3.0.0,>=2.1.0->rich<14,>=10.14.0->streamlit->simpletransformers) (0.1.2)

# %%
train_x_y = df.sample(frac = 0.75, random_state = 42)
test_x_y = pd.concat([df, train_x_y]).drop_duplicates(keep=False)

# %%
print(train_x_y.shape)
print(test_x_y.shape)
# Out:
# (3630, 2)
# (1169, 2)

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs


model_args = ClassificationArgs()
model_args.train_batch_size = 2
model_args.gradient_accumulation_steps = 8
model_args.learning_rate = 3e-5
model_args.num_train_epochs = 1

model_bert = ClassificationModel("bert", "distilbert-base-cased", num_labels=3, args=model_args, use_cuda=False)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# (…)base-uncased/resolve/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
model_bert.train_model(train_x_y)
# Out:
#   0%|          | 0/3630 [00:00<?, ?it/s]

# %%
pred_bert, out_bert = model_bert.predict(test_x_y['text'].values)

acc_bert = accuracy_score(test_x_y['labels'].to_numpy(), pred_bert)
f1_bert = f1_score(test_x_y['labels'].to_numpy(), pred_bert, average='micro')

print("Accuracy score -->", acc_bert)
print("F1 score -->", f1_bert)

# %%
#graph with confusion matrix

cm = confusion_matrix(pred_bert, test_x_y['labels'].to_numpy())
#group_names = ["True Neg","False Pos","False Neg","True Pos"]
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
labels = [f"{v1}\n{v2}" for v1, v2 in zip(group_counts,group_percentages)]
labels = np.asarray(labels).reshape(3,3)
sns.heatmap(cm, annot=labels, fmt="", cmap='Blues')
plt.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
sns.regplot(x=pred_bert, y=test_x_y['labels'].to_numpy(),marker="*")
plt.show()
